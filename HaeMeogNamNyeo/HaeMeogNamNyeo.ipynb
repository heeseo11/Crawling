# %%
from selenium import webdriver as wd
from bs4 import BeautifulSoup
import time
import re
import requests

# %%
URL =  "https://haemukja.com/recipes?cooking_time=&difficulty=&healthy=&name=%EB%96%A1&page={}&sort="

# %%
all_url = []
for i in range(0,22):
    url = URL.format(i)
    print(url)
    
    r = requests.get(URL)
    soup = BeautifulSoup(r.text, 'html.parser')
    
    for i in range(len(soup.findAll('a',attrs={'class':'call_recipe thmb'}))):
        href = soup.findAll('a',attrs={'class':'call_recipe thmb'})[i]['href']
        rec_url = "https://haemukja.com{}".format(href)
        all_url.append(rec_url)
# Out:
# https://haemukja.com/recipes?cooking_time=&difficulty=&healthy=&name=%EB%96%A1&page=0&sort=
# https://haemukja.com/recipes?cooking_time=&difficulty=&healthy=&name=%EB%96%A1&page=1&sort=
# https://haemukja.com/recipes?cooking_time=&difficulty=&healthy=&name=%EB%96%A1&page=2&sort=
# https://haemukja.com/recipes?cooking_time=&difficulty=&healthy=&name=%EB%96%A1&page=3&sort=
# https://haemukja.com/recipes?cooking_time=&difficulty=&healthy=&name=%EB%96%A1&page=4&sort=
# https://haemukja.com/recipes?cooking_time=&difficulty=&healthy=&name=%EB%96%A1&page=5&sort=
# https://haemukja.com/recipes?cooking_time=&difficulty=&healthy=&name=%EB%96%A1&page=6&sort=
# https://haemukja.com/recipes?cooking_time=&difficulty=&healthy=&name=%EB%96%A1&page=7&sort=
# https://haemukja.com/recipes?cooking_time=&difficulty=&healthy=&name=%EB%96%A1&page=8&sort=
# https://haemukja.com/recipes?cooking_time=&difficulty=&healthy=&name=%EB%96%A1&page=9&sort=
# ...

# %%
len(all_url)
# Out:
# 264

# %%
for i in all_url:
    r = requests.get(i)
    soup = BeautifulSoup(r.text, 'html.parser')
    
    # 레시피 순서
    rec_order = soup.findAll('ol', attrs = {'class':'lst_step'})[0].get_text().replace("\n","")
# Out:
# https://haemukja.com/recipes/5961
# https://haemukja.com/recipes/5945
# https://haemukja.com/recipes/5882
# https://haemukja.com/recipes/5856
# https://haemukja.com/recipes/5811
# https://haemukja.com/recipes/5795
# https://haemukja.com/recipes/5792
# https://haemukja.com/recipes/5782
# https://haemukja.com/recipes/5769
# https://haemukja.com/recipes/5744
# https://haemukja.com/recipes/5731
# https://haemukja.com/recipes/5718
# https://haemukja.com/recipes/5961
# https://haemukja.com/recipes/5945
# https://haemukja.com/recipes/5882
# https://haemukja.com/recipes/5856
# https://haemukja.com/recipes/5811
# https://haemukja.com/recipes/5795
# https://haemukja.com/recipes/5792
# https://haemukja.com/recipes/5782
# https://haemukja.com/recipes/5769
# https://haemukja.com/recipes/5744
# https://haemukja.com/recipes/5731
# https://haemukja.com/recipes/5718
# https://haemukja.com/recipes/5961
# https://haemukja.com/recipes/5945
# https://haemukja.com/recipes/5882
# ...

# %%
#container > div.inpage-recipe > div > div.view_recipe > section.sec_detail > section.sec_rcp_step > ol > li:nth-child(1) > p
# Out:
# 'https://haemukja.com/recipes/5961'

# %%
r = requests.get(all_url[0])

# %%
r
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="해먹남녀" name="application-name"/>
# <meta content="width=960" name="viewport"/>
# <meta content="cqRCL1akKoGWvgLrQIOlQqTzl85WRgOOCo64qsyQ4P0" name="google-site-verification">
# <title>단짠단짠 궁중떡볶이해먹 - 누구나 따라할수있는 맛있고 건강한 레시피 추천</title>
# <link href="/favicon.ko.ico" rel="icon" type="image/x-icon"/>
# <meta content="해먹 크리에이터" name="author"/>
# <meta content="요리만찬 - 아이들도 좋아하는 간장떡볶이 재료: 가래떡,소고기,당근,양파,대파,표고버섯,파프리카,참기름,굴소스,간장,올리고당,맛술,다진마늘 조리순서: 1.가래떡을 6cm길이로 4등분 해줍니다.(총320g). 칼에 참기름을 바르면 떡이 안 달라 붙습니다.
#
# 2.표고버섯, 파프리카, 양파를 썰어줍니다. 대파, 당근을 썰어줍니다.
#
# 3.떡이 단단할 경우 살짝 데쳐 준 후 기름장 양념 (간장 반스푼, 참기름 반스푼)을 넣고 버무립니다.
#
# 4.키친타월로 소고기 핏물 제거를 해줍니다.
#
# 5.소고기에 양념 (간장 1스푼, 맛술 1스푼, 올리고당 1스푼, 다진마늘1/3스푼,참기름1스푼, 후춧가루)을 해서 버무려줍니다.
#
# 6.떡볶이 양념을 만들어 줍니다.(간장1스푼, 올리고당1스푼, 다진마늘1/2스푼, 굴소스1/2스푼)
#
# 7.달군 팬에 식용유 두르고 소고기 먼저 볶아 줍니다. 어느정도 익으면 떡과 야채를 넣고 볶아 줍니다.
#
# ...

# %%
soup.findAll('p',attrs={'style':'display:none;'})[2].get_text()
# Out:
# '단백질 23.3g (42.3%)'

# %%
soup.select('#container > div.inpage-recipe > div > div.view_recipe > section.sec_info > div > div.btm > ul > li:nth-of-type(4) > span')[0].text
# Out:
# '양파'

# %%
soup.findAll('ol', attrs = {'class':'lst_step'})[0].get_text().replace("\n","")
# Out:
# '1.가래떡을 6cm길이로 4등분 해줍니다.(총320g). 칼에 참기름을 바르면 떡이 안 달라 붙습니다.2.표고버섯, 파프리카, 양파를 썰어줍니다. 대파, 당근을 썰어줍니다.3.떡이 단단할 경우 살짝 데쳐 준 후 기름장 양념 (간장 반스푼, 참기름 반스푼)을 넣고 버무립니다.4.키친타월로 소고기 핏물 제거를 해줍니다.5.소고기에 양념 (간장 1스푼, 맛술 1스푼, 올리고당 1스푼, 다진마늘1/3스푼,참기름1스푼, 후춧가루)을 해서 버무려줍니다.6.떡볶이 양념을 만들어 줍니다.(간장1스푼, 올리고당1스푼, 다진마늘1/2스푼, 굴소스1/2스푼)7.달군 팬에 식용유 두르고 소고기 먼저 볶아 줍니다. 어느정도 익으면 떡과 야채를 넣고 볶아 줍니다.8.떡볶이 양념장을 넣어 간을 맞춥니다.(간을 보고 더 넣으셔도 됩니다.) 탈 것 같으면 물을 넣어주세요.9.참기름 살짝 두르고 통깨를 뿌리면 완성!'
